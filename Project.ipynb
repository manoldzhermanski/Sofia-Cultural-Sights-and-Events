# %% [markdown]
# # Import needed libraries

# %%
import requests
from bs4 import BeautifulSoup
import psycopg2

# %% [markdown]
# # Scrape all links for the galleries

# %%
import requests
from bs4 import BeautifulSoup

# Set to store unique URLs
unique_urls = set()

# URL of the site to scrape
url = f"https://sofia-art-galleries.com/cat/galerii-i-muzei-v-sofia/"

# Send a GET request to the site
response = requests.get(url)
response.raise_for_status()  # Check if the request was successful

# Parse the HTML content
soup = BeautifulSoup(response.text, 'html.parser')

# Find all <a> elements with href starting with 'https://sofia-art-galleries.com/item/'
item_links = soup.find_all('a', href=lambda href: href and href.startswith('https://sofia-art-galleries.com/item/'))

# Extract and print the href attribute of each <a> tag
for link in item_links:
    href = link['href']
    # Check if the URL is unique
    if href not in unique_urls:
        print(href)
        unique_urls.add(href)
# Out:
# https://sofia-art-galleries.com/item/hostgallery/
# https://sofia-art-galleries.com/item/little-bird-place-galeriya-i-sabitiya/
# https://sofia-art-galleries.com/item/atelie-plastelin/
# https://sofia-art-galleries.com/item/galeriya-plus-359/
# https://sofia-art-galleries.com/item/galeriya-antikvariat-velev/
# https://sofia-art-galleries.com/item/galeriya-auktsionna-kashta-enakor/
# https://sofia-art-galleries.com/item/galeriya-88-kamen-popov/
# https://sofia-art-galleries.com/item/galeriya-artvibes/

# %%
# Set to store unique URLs
unique_urls = set()

for i in range(2, 9):
    # URL of the site to scrape
    url = f"https://sofia-art-galleries.com/cat/galerii-i-muzei-v-sofia/page/{i}/"
    
    # Send a GET request to the site
    response = requests.get(url)
    response.raise_for_status()  # Check if the request was successful

    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all <a> elements with href starting with 'https://sofia-art-galleries.com/item/'
    item_links = soup.find_all('a', href=lambda href: href and href.startswith('https://sofia-art-galleries.com/item/'))

    # Extract and print the href attribute of each <a> tag
    for link in item_links:
        href = link['href']
        # Check if the URL is unique
        if href not in unique_urls:
            print(href)
            unique_urls.add(href)
# Out:
# https://sofia-art-galleries.com/item/galeriya-blenda/
# https://sofia-art-galleries.com/item/galeriya-credo-bonum/
# https://sofia-art-galleries.com/item/galeriya-depoo/
# https://sofia-art-galleries.com/item/galeriya-integrated-artists/
# https://sofia-art-galleries.com/item/galeriya-one/
# https://sofia-art-galleries.com/item/galeriya-ramjuly/
# https://sofia-art-galleries.com/item/galeriya-spazio/
# https://sofia-art-galleries.com/item/a-cube-galeriya-za-savremenno-izkustvo/
# https://sofia-art-galleries.com/item/galeriya-absent/
# https://sofia-art-galleries.com/item/galeriya-akademiya/
# https://sofia-art-galleries.com/item/galeriya-arosita/
# https://sofia-art-galleries.com/item/galeriya-art-aleya/
# https://sofia-art-galleries.com/item/galeriya-artcenter-12/
# https://sofia-art-galleries.com/item/galeriya-arte/
# https://sofia-art-galleries.com/item/galeriya-artur/
# https://sofia-art-galleries.com/item/galeriya-astri/
# https://sofia-art-galleries.com/item/galeriya-b61/
# ...

# %% [markdown]
# # List all unique URLs

# %% [markdown]
# # Scrape their longitude and latitude

# %%
# Function to scrape latitude and longitude from a single URL
def scrape_lat_long(url):
    # Send a GET request to the site
    response = requests.get(url)
    response.raise_for_status()  # Check if the request was successful

    # Parse the HTML content
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the div with class 'cd-data' and itemtype 'http://schema.org/GeoCoordinates'
    geo_div = soup.find('div', class_='cd-data', itemtype='http://schema.org/GeoCoordinates')
    
    if geo_div:
        # Find the meta tags for latitude and longitude
        latitude_meta = geo_div.find('meta', itemprop='latitude')
        longitude_meta = geo_div.find('meta', itemprop='longitude')
        
        if latitude_meta and longitude_meta:
            latitude = latitude_meta['content']
            longitude = longitude_meta['content']
            return latitude, longitude
    
    return None, None

# Loop through the URLs and scrape the latitude and longitude
for url in unique_urls:
    latitude, longitude = scrape_lat_long(url)
    if latitude and longitude:
        print(f"URL: {url}\nLatitude: {latitude}\nLongitude: {longitude}\n")
    else:
        print(f"URL: {url}\nLatitude and Longitude not found\n")
# Out:
# URL: https://sofia-art-galleries.com/item/galeriya-kontrast/
# Latitude: 42.694313602737
# Longitude: 23.316952522095
#
# URL: https://sofia-art-galleries.com/item/galeriya-loran/
# Latitude and Longitude not found
#
# URL: https://sofia-art-galleries.com/item/galeriya-minerva/
# Latitude: 42.693887
# Longitude: 23.324546
#
# URL: https://sofia-art-galleries.com/item/galeriya-stubel/
# Latitude: 42.676924216947
# Longitude: 23.357817399067
#
# URL: https://sofia-art-galleries.com/item/galeriya-parizh/
# Latitude: 42.69406592576
# Longitude: 23.316864578773
#
# URL: https://sofia-art-galleries.com/item/galeriya-noy/
# Latitude: 42.697221
# Longitude: 23.331266
#
# URL: https://sofia-art-galleries.com/item/muzei-boris-hristov/
# Latitude: 42.6937315
# Longitude: 23.3165937
#
# URL: https://sofia-art-galleries.com/item/galeriya-balgari/
# Latitude: 42.6990373
# Longitude: 23.3367855
#
# URL: https://sofia-art-galleries.com/item/galeriya-slon/
# Latitude: 42.692054284949
# ...

# %%
# Connect to your PostgreSQL database
conn = psycopg2.connect(
    dbname="ragis",
    user="midzherman",
    password="ragis2024midftw",
    host="34.118.61.196",
    options="-c search_path=midzherman_work"
)

# Open a cursor to perform database operations
cur = conn.cursor()

# Assuming you have a spreadsheet with the following columns: url, longitude, latitude
# Replace 'Scraped_Galleries.csv' with the path to your actual spreadsheet
with open('Scraped_Galleries.csv', 'r') as f:
    next(f)  # Skip the header row
    for line in f:
        data = line.strip().split(',')
        #name = data[0]  # Uncomment this line if you have a 'name' column in your CSV
        url = data[0]
        longitude = float(data[1])
        latitude = float(data[2])

        # Construct the WKT representation of the point geometry
        geom_wkt = f"POINT({longitude}, {latitude})"

        # Insert the data into the database
        cur.execute("INSERT INTO galleries(url, location) VALUES(%s, ST_GeomFromText(%s, 7803))", (url, geom_wkt))

# Commit the transaction
conn.commit()

# Close the cursor and connection
cur.close()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# UndefinedFunction                         Traceback (most recent call last)
# Cell In[34], line 28
#      25         geom_wkt = f"POINT({longitude}, {latitude})"
#      27         # Insert the data into the database
# ---> 28         cur.execute("INSERT INTO galleries(url, location) VALUES(%s, ST_GeomFromText(%s, 7803))", (url, geom_wkt))
#      30 # Commit the transaction
#      31 conn.commit()
#
# UndefinedFunction: function st_geomfromtext(unknown, integer) does not exist
# LINE 1: ...tps://sofia-art-galleries.com/item/hostgallery/', ST_GeomFro...
#                                                              ^
# HINT:  No function matches the given name and argument types. You might need to add explicit type casts.

# %%
from bs4 import BeautifulSoup
import re

# Sample HTML content
html_content = '''
<iframe style="height:100%;width:100%;border:0;" frameborder="0" referrerpolicy="no-referrer-when-downgrade" src="https://www.google.com/maps/embed/v1/place?key=AIzaSyBX99sMFg9_Aj6RAd2Hveb6rsiGWvfNSSM&amp;q=%D0%B1%D1%83%D0%BB.+%E2%80%9E%D0%A6%D0%B0%D1%80%D0%B8%D0%B3%D1%80%D0%B0%D0%B4%D1%81%D0%BA%D0%BE+%D1%88%D0%BE%D1%81%D0%B5%E2%80%9C+115%2C+%D0%A1%D0%BE%D1%84%D0%B8%D1%8F%2C+%D0%91%D1%8A%D0%BB%D0%B3%D0%B0%D1%80%D0%B8%D1%8F&amp;center=42.6638984,23.3786643&amp;zoom=16&amp;language=bg_BG" allowfullscreen=""></iframe>
'''

# Parse the HTML content
soup = BeautifulSoup(html_content, 'html.parser')

# Find the iframe tag
iframe_tag = soup.find('iframe')

# Extract the src attribute
src = iframe_tag['src']

# Use a regex to find the latitude and longitude
match = re.search(r'center=([-+]?\d*\.\d+),([-+]?\d*\.\d+)', src)

if match:
    latitude = match.group(1)
    longitude = match.group(2)
    print(f'Latitude: {latitude}, Longitude: {longitude}')
else:
    print('Coordinates not found')
# Out:
# Latitude: 42.6638984, Longitude: 23.3786643

# %%
import pandas as pd
from bs4 import BeautifulSoup

def extract_text_from_links(links):
  """
  Extracts text between `<div class="theatre">` and `</div>` tags from a list of links.

  Args:
    links: List of strings containing the HTML code with the target tags.

  Returns:
    A list of strings containing the extracted text from each link, or None if not found.
  """
  extracted_texts = []
  for link in links:
    soup = BeautifulSoup(link, 'html.parser')
    theatre_div = soup.find("div", class_="theatre")
    if theatre_div:
      # Consider removing all child elements (except text) for cleaner extraction
      theatre_text = theatre_div.get_text(strip=True, separator='\n')
      extracted_texts.append(theatre_text.strip())  # Remove extra whitespaces
    else:
      extracted_texts.append(None)
  return extracted_texts

# Example usage (replace 'your_links' with your actual list of links)
your_links = [
"https://theatre.art.bg/the-fridge-%D1%85%D0%B0%D1%81%D0%BF%D0%B5%D0%BB-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___127___20",
"https://theatre.art.bg/art-space-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___117___20",
"https://theatre.art.bg/a%D1%82%D0%B5%D0%BB%D0%B8%D0%B5-%D0%BF%D0%BB%D0%B0%D1%81%D1%82%D0%B5%D0%BB%D0%B8%D0%BD-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___161___20",
"https://theatre.art.bg/boulevard-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___158___20",
"https://theatre.art.bg/cherry-entertainment-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___182___20",
"https://theatre.art.bg/desta-production-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___222___20",
"https://theatre.art.bg/i-am-studio-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___232___20",
"https://theatre.art.bg/playback-%D1%82%D0%B5%D0%B0%D1%82%D1%8A%D1%80-%D1%82%D1%83%D0%BA-%D0%B8-%D1%81%D0%B5%D0%B3%D0%B0-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___138___20",
"https://theatre.art.bg/spam-studios-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___195___20",
"https://theatre.art.bg/the-art-foundation-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___175___20",
"https://theatre.art.bg/the-balkan-theatre-factory-%D1%81%D0%BE%D1%84%D0%B8%D1%8F
%D1%81%D0%BE%D1%84%D0%B8%D1%8F___191___20",
"https://theatre.art.bg/%D1%82%D0%B5%D0%B0%D1%82%D1%8A%D1%80-199-%D0%B2%D0%B0%D0%BB%D0%B5%D0%BD%D1%82%D0%B8%D0%BD-%D1%81%D1%82%D0%BE%D0%B9%D1%87%D0%B5%D0%B2-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___8___20",
"https://theatre.art.bg/%D1%82%D0%B5%D0%B0%D1%82%D1%8A%D1%80-%D0%B0%D1%82%D0%B5%D0%BB%D0%B8%D0%B5-313-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___22___20"
]
extracted_data = extract_text_from_links(your_links)

# Print or use the extracted data (extracted_texts) as needed
for text in extracted_data:
  if text:
    print(text)
  else:
    print("Text not found in this link.")
# Out:
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# Text not found in this link.
# ...

# %%
import requests
from bs4 import BeautifulSoup

def extract_text_from_div(url):
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    
    try:
        response = requests.get(url, headers=headers)
        response.raise_for_status()
        
        soup = BeautifulSoup(response.text, 'html.parser')
        div_tag = soup.find('div', class_='theatre')
        
        if div_tag:
            return div_tag.get_text(strip=True)
        else:
            return "No 'theatre' div found"
    except requests.RequestException as e:
        return f"Error fetching {url}: {e}"


# Extract text from each URL
for url in your_links:
    text = extract_text_from_div(url)
    print(f"URL: {url}\nText: {text}\n")

# If you need to save the results to a file, uncomment the lines below:
# with open('results.txt', 'w', encoding='utf-8') as file:
#     for url in urls:
#         text = extract_text_from_div(url)
#         file.write(f"URL: {url}\nText: {text}\n\n")
# Out:
# URL: https://theatre.art.bg/the-fridge-%D1%85%D0%B0%D1%81%D0%BF%D0%B5%D0%BB-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___127___20
# Text: София, бул. "Мадрид" 8,  http://the--fridge.blogspot.com/
#
# URL: https://theatre.art.bg/art-space-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___117___20
# Text: София 1000, 0899 710 702, 	0889 898 058,  Art Space - лятна сцена до НДК
#
# URL: https://theatre.art.bg/a%D1%82%D0%B5%D0%BB%D0%B8%D0%B5-%D0%BF%D0%BB%D0%B0%D1%81%D1%82%D0%B5%D0%BB%D0%B8%D0%BD-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___161___20
# Text: София, ул. "цар Симеон" 48
# ,  0899 89 55 21 - за резервация.
# Билети се продават на място.
#
# URL: https://theatre.art.bg/boulevard-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___158___20
# Text: София, ул. Атанас Дуков 29, зала
# Rainbow Plaza,  0897 949 313
#
# URL: https://theatre.art.bg/cherry-entertainment-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___182___20
# Text: София,  0886046859
#
# URL: https://theatre.art.bg/desta-production-%D1%81%D0%BE%D1%84%D0%B8%D1%8F___222___20
# ...

# %%
from geopy.geocoders import Nominatim

def get_lat_long(address):
    geolocator = Nominatim(user_agent="geoapiExercises")
    location = geolocator.geocode(address)
    
    if location:
        return location.latitude, location.longitude
    else:
        raise Exception("Address not found")

# Example usage
address = "бул. Мадрид 8, София, България"
latitude, longitude = get_lat_long(address)
print(f'Latitude:\n{latitude}\nLongitude:\n{longitude}')
# Out:
# ---------------------------------------------------------------------------
# AdapterHTTPError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\geopy\geocoders\base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\geopy\adapters.py:472, in RequestsAdapter.get_json(self, url, timeout, headers)
#     471 def get_json(self, url, *, timeout, headers):
# --> 472     resp = self._request(url, timeout=timeout, headers=headers)
#     473     try:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\geopy\adapters.py:500, in RequestsAdapter._request(self, url, timeout, headers)
#     499     if resp.status_code >= 400:
# --> 500         raise AdapterHTTPError(
# ...
